# %% [markdown]
# # TP: Machine Learning (SIA_3611)
#
# ## TP1: Linear Regression (4h)
#
# by Clément Bouvier
#
# Linear regression is a family of machine learning algorithms aiming at adjusting a linear model to an ensemble of data. The applications range from signal reconstruction to empirical description.
#
# The given dataset was produced by the World Health Organization. It pooled the evolution of 20 features for 15 years and among numerous countries. One of the goals of this TP1 is to manipulate this dataset and try to predict the evolution of Life Expectancy through different variables.
#
# **Objectives:**
# - Use and setup an iPython environment
# - Manipulate and visualize data
# - Implement a simple linear regression
# - Apply the aforementioned linear regression
# - Compute a $R^2$ on the generated results
# - Apply Ridge and Lasso regressions

# %% [markdown]
# ## STEP 1: Use and setup an iPython environment

# %% [markdown]
# iPython and Notebook environments are useful tools to quickly prototype and test machine learning solutions. However, they have limitations especially in RAM and disk access.

# %% [markdown]
# **TO DO 1.1**
#
# Execute the following cells

# %%
a = 3
b = 4
c = a + b

# %%
c = c

# %%
print(c)
# Out:
# 7

# %%
c
# Out:
# 7

# %% [markdown]
# **QUESTION 1**
#
# **What is triggering the output display?** Appeler la variable en dernière ligne de cellule ou utiliser une fonction d'affichage (print par exemple )

# %% [markdown]
# **TO DO 1.2**
#
# Execute the following cells

# %%
import shutil
import pkgutil

def show_acceptable_modules():
    line = '-' * 100
    print('{}\n{:^30}|{:^20}\n{}'.format(line, 'Module', 'Location', line))
    for entry in pkgutil.iter_modules():
        print('{:30}| {}'.format(entry[1], entry[0].path))

# %%
show_acceptable_modules()
# Out:
# ----------------------------------------------------------------------------------------------------
#             Module            |      Location
# ----------------------------------------------------------------------------------------------------
# aggregateTestResults          | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# completion                    | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# get-pip                       | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# install_debugpy               | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# interpreterInfo               | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# normalizeForInterpreter       | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# normalizeSelection            | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# printEnvVariables             | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# printEnvVariablesToFile       | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# printJupyWidgetEntryPoints    | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# printJupyterDataDir           | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# runJediLanguageServer         | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# shell_exec                    | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# symbolProvider                | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# testlauncher                  | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# visualstudio_py_testlauncher  | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# vscode_datascience_helpers    | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles
# pyls_jsonrpc                  | /Users/yohanismael/.vscode/extensions/ms-toolsai.jupyter-2022.9.1202862440/pythonFiles/lib/python
# __future__                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _aix_support                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _bootlocale                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _bootsubprocess               | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _collections_abc              | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _compat_pickle                | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _compression                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _markupbase                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _osx_support                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _py_abc                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _pydecimal                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _pyio                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _sitebuiltins                 | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _strptime                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _sysconfigdata__darwin_darwin | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _sysconfigdata_x86_64_apple_darwin13_4_0| /Users/yohanismael/opt/anaconda3/lib/python3.9
# _threading_local              | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _weakrefset                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# abc                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# aifc                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# antigravity                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# argparse                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ast                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# asynchat                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# asyncio                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# asyncore                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# base64                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# bdb                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# binhex                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# bisect                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# bz2                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# cProfile                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# calendar                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# cgi                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# cgitb                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# chunk                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# cmd                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# code                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# codecs                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# codeop                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# collections                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# colorsys                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# compileall                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# concurrent                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# configparser                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# contextlib                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# contextvars                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# copy                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# copyreg                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# crypt                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# csv                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ctypes                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# curses                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# dataclasses                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# datetime                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# dbm                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# decimal                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# difflib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# dis                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# distutils                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# doctest                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# email                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# encodings                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ensurepip                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# enum                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# filecmp                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# fileinput                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# fnmatch                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# formatter                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# fractions                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ftplib                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# functools                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# genericpath                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# getopt                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# getpass                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# gettext                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# glob                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# graphlib                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# gzip                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# hashlib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# heapq                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# hmac                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# html                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# http                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# idlelib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# imaplib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# imghdr                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# imp                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# importlib                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# inspect                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# io                            | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ipaddress                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# json                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# keyword                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# lib2to3                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# linecache                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# locale                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# logging                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# lzma                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# mailbox                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# mailcap                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# mimetypes                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# modulefinder                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# multiprocessing               | /Users/yohanismael/opt/anaconda3/lib/python3.9
# netrc                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# nntplib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ntpath                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# nturl2path                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# numbers                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# opcode                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# operator                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# optparse                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# os                            | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pathlib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pdb                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pickle                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pickletools                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pipes                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pkgutil                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# platform                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# plistlib                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# poplib                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# posixpath                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pprint                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# profile                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pstats                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pty                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# py_compile                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pyclbr                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pydoc                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# pydoc_data                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# queue                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# quopri                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# random                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# re                            | /Users/yohanismael/opt/anaconda3/lib/python3.9
# reprlib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# rlcompleter                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# runpy                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sched                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# secrets                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# selectors                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# shelve                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# shlex                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# shutil                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# signal                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# site                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# smtpd                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# smtplib                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sndhdr                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# socket                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# socketserver                  | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sqlite3                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sre_compile                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sre_constants                 | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sre_parse                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# ssl                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# stat                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# statistics                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# string                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# stringprep                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# struct                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# subprocess                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sunau                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# symbol                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# symtable                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# sysconfig                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tabnanny                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tarfile                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# telnetlib                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tempfile                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# test                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# textwrap                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# this                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# threading                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# timeit                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tkinter                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# token                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tokenize                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# trace                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# traceback                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tracemalloc                   | /Users/yohanismael/opt/anaconda3/lib/python3.9
# tty                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# turtle                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# turtledemo                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# types                         | /Users/yohanismael/opt/anaconda3/lib/python3.9
# typing                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# unittest                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# urllib                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# uu                            | /Users/yohanismael/opt/anaconda3/lib/python3.9
# uuid                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# venv                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# warnings                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# wave                          | /Users/yohanismael/opt/anaconda3/lib/python3.9
# weakref                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# webbrowser                    | /Users/yohanismael/opt/anaconda3/lib/python3.9
# wsgiref                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# xdrlib                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# xml                           | /Users/yohanismael/opt/anaconda3/lib/python3.9
# xmlrpc                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# zipapp                        | /Users/yohanismael/opt/anaconda3/lib/python3.9
# zipfile                       | /Users/yohanismael/opt/anaconda3/lib/python3.9
# zipimport                     | /Users/yohanismael/opt/anaconda3/lib/python3.9
# zoneinfo                      | /Users/yohanismael/opt/anaconda3/lib/python3.9
# _asyncio                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _bisect                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _blake2                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _bz2                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_cn                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_hk                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_iso2022               | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_jp                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_kr                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _codecs_tw                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _contextvars                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _crypt                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _csv                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _ctypes                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _ctypes_test                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _curses                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _curses_panel                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _datetime                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _dbm                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _decimal                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _elementtree                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _hashlib                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _heapq                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _json                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _lsprof                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _lzma                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _md5                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _multibytecodec               | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _multiprocessing              | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _opcode                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _pickle                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _posixshmem                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _posixsubprocess              | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _queue                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _random                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _scproxy                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _sha1                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _sha256                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _sha3                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _sha512                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _socket                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _sqlite3                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _ssl                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _statistics                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _struct                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _testbuffer                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _testcapi                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _testimportmultiple           | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _testinternalcapi             | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _testmultiphase               | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _tkinter                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _uuid                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _xxsubinterpreters            | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _xxtestfuzz                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# _zoneinfo                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# array                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# audioop                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# binascii                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# cmath                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# fcntl                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# grp                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# math                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# mmap                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# nis                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# parser                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# pyexpat                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# readline                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# resource                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# select                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# syslog                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# termios                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# unicodedata                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# xxlimited                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# zlib                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/lib-dynload
# Cython                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# IPython                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# OpenSSL                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# PIL                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# PyQt5                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# TBB                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _argon2_cffi_bindings         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _black_version                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _cffi_backend                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _distutils_hack               | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _plotly_future_               | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _plotly_utils                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _pyrsistent_version           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _pytest                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _watchdog_fsevents            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# _yaml                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# aiohttp                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# aiosignal                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# alabaster                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# anaconda_navigator            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# anaconda_project              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# anyio                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# appdirs                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# applaunchservices             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# appnope                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# argon2                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# arrow                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# astroid                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# astropy                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# asttokens                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# async_timeout                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# atomicwrites                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# attr                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# attrs                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# automat                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# autopep8                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# babel                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# backcall                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# backports                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bcrypt                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# binaryornot                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# binstar_client                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bitarray                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bkcharts                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# black                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# blackd                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bleach                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# blib2to3                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bokeh                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# boto3                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# botocore                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bottleneck                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# brotli                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# bs4                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cachetools                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# certifi                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cffi                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# chardet                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# charset_normalizer            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# click                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cloudpickle                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# clyent                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# colorama                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# colorcet                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_build                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_content_trust           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_env                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_pack                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_package_handling        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_token                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# conda_verify                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# constantly                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cookiecutter                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cryptography                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cssselect                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# curl                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cv2                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cycler                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cython                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# cytoolz                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# daal4py                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# dask                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# datashader                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# datashape                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# dateutil                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# debugpy                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# decorator                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# defusedxml                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# diff_match_patch              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# distributed                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# docutils                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# entrypoints                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# erfa                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# et_xmlfile                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# executing                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# fastjsonschema                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# filelock                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# flake8                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# flask                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# fontTools                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# frozenlist                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# fsspec                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# future                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# gensim                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# glob2                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# gmpy2                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# google_crc32c                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# greenlet                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# grpc                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# h5py                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# hamcrest                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# heapdict                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# holoviews                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# hvplot                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# hyperlink                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# idna                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# imagecodecs                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# imageio                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# imagesize                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# importlib_metadata            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# incremental                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# inflection                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# iniconfig                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# intake                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# intervaltree                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ipykernel                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ipykernel_launcher            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ipython_genutils              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ipywidgets                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# isort                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# isympy                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# itemadapter                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# itemloaders                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# itsdangerous                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jdcal                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jedi                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jinja2                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jinja2_time                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jmespath                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# joblib                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# json5                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jsonschema                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyter                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyter_client                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyter_console               | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyter_core                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyter_server                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyterlab                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyterlab_plotly             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyterlab_pygments           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyterlab_server             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jupyterlab_widgets            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# jwt                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# keras                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# keyring                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# kiwisolver                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# lazy_object_proxy             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# libarchive                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# libfuturize                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# libpasteurize                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# lief                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# llvmlite                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# locket                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# lxml                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# markdown                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# markupsafe                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# matplotlib                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# matplotlib_inline             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mccabe                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mistune                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mkl                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mkl_fft                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mkl_random                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mock                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mpmath                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# msgpack                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# multidict                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# multipledispatch              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# munkres                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# mypy_extensions               | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# navigator_updater             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nbclassic                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nbclient                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nbconvert                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nbformat                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nest_asyncio                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# networkx                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nltk                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# nose                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# notebook                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# numba                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# numbergen                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# numexpr                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# numpy                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# numpydoc                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# olefile                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# onedal                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# openpyxl                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# packaging                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pandas                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pandocfilters                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# panel                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# param                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# parsel                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# parso                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# partd                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# past                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pathspec                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# patsy                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pep8                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pexpect                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pickleshare                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pip                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pkg_resources                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pkginfo                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# plotly                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pluggy                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# poyo                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# prometheus_client             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# prompt_toolkit                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# protego                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# psutil                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ptyprocess                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pure_eval                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pvectorc                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# py                            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyasn1                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyasn1_modules                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pycodestyle                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pycosat                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pycparser                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyct                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pycurl                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pydispatch                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pydocstyle                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyflakes                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pygments                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pylab                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pylint                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyls_spyder                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pylsp                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pylsp_black                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pylsp_jsonrpc                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyodbc                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyparsing                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyrsistent                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pytest                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pytz                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyviz_comms                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pywt                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# pyximport                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# qdarkstyle                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# qstylizer                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# qtawesome                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# qtconsole                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# qtpy                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# queuelib                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# regex                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# repo_cli                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# requests                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# requests_file                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# rope                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# rsa                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# rtree                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ruamel_yaml                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# s3transfer                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# scipy                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# scrapy                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# seaborn                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# send2trash                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# service_identity              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# setuptools                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sip                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sipconfig                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sipdistutils                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# six                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# skimage                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sklearn                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sklearnex                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# slugify                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# smart_open                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# snappy                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sniffio                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# snowballstemmer               | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# socks                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sockshandler                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sortedcollections             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sortedcontainers              | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# soupsieve                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sphinx                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# spyder                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# spyder_kernels                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sqlalchemy                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# stack_data                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# statsmodels                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# sympy                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tables                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tabulate                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tbb                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tblib                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tenacity                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# terminado                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# test_pycosat                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# testpath                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# text_unidecode                | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# textdistance                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# threadpoolctl                 | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# three_merge                   | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tifffile                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tinycss                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tldextract                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tlz                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# toml                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tomli                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# toolz                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tornado                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# tqdm                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# traitlets                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# twisted                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# typed_ast                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# typing_extensions             | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# ujson                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# unidecode                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# urllib3                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# w3lib                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# watchdog                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# wcwidth                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# webencodings                  | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# websocket                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# werkzeug                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# wheel                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# widgetsnbextension            | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# wrapt                         | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# wurlitzer                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# xarray                        | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# xlrd                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# xlsxwriter                    | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# xlwings                       | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# yaml                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# yapf                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# yapftests                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# yarl                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# zict                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# zipp                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# zmq                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# zope                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages
# aem                           | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/aeosa
# appscript                     | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/aeosa
# mactypes                      | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/aeosa
# osax                          | /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/aeosa

# %% [markdown]
# **QUESTION 2**
#
# **What is displayed on the last output?** Les modules disponibles et leur chemin d'accès
#
# **Which is the used Python version?** C'est la version 3.9
#
# For this TP1, you will need:
# - pandas
# - matplotlib
# - numpy
# - sklearn
#
# **Are these packages installed in this environment?** Yes

# %% [markdown]
# **TO DO 1.3**
#
# Execute the following cell

# %%
pandas.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yohanismael/Documents/Ecole/3A/COURS/ENSEA/Machine Learning/TP/TP1/TP1_LinearRegression.ipynb Cellule 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yohanismael/Documents/Ecole/3A/COURS/ENSEA/Machine%20Learning/TP/TP1/TP1_LinearRegression.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> pandas.__version__
#
# NameError: name 'pandas' is not defined

# %% [markdown]
# **QUESTION 3**
#
# **How would you solve this error?** Il faut importer pandas

# %% [markdown]
# ## STEP 2: Data manipulation and visualization

# %% [markdown]
# **TO DO 2.1**
#
# Execute the following cell

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/Life_Expectancy_Data.csv")
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1649 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Longitude                        1649 non-null   float64
#  2   Latitude                         1649 non-null   float64
#  3   Continent                        1649 non-null   object
#  4   Year                             1649 non-null   int64
#  5   Status                           1649 non-null   object
#  6   Life_expectancy                  1649 non-null   float64
#  7   Adult_mortality                  1649 non-null   float64
#  8   Infant_deaths                    1649 non-null   int64
#  9   Alcohol                          1649 non-null   float64
#  10  Percentage_expenditure           1649 non-null   float64
#  11  Hepatitis_B                      1649 non-null   float64
#  12  Measles                          1649 non-null   int64
#  13  BMI                              1649 non-null   float64
#  14  Under-five_deaths                1649 non-null   int64
#  15  Polio                            1649 non-null   float64
#  16  Total_expenditure                1649 non-null   float64
#  17  Diphtheria                       1649 non-null   float64
#  18  HIV_AIDS                         1649 non-null   float64
#  19  GDP                              1649 non-null   float64
#  20  Population                       1649 non-null   float64
#  21  Thinness _1-19_years             1649 non-null   float64
#  22  Thinness_5-9_years               1649 non-null   float64
#  23  Income_composition_of_resources  1649 non-null   float64
#  24  Schooling                        1649 non-null   float64
# dtypes: float64(18), int64(4), object(3)
# memory usage: 335.0+ KB

# %% [markdown]
# **QUESTION 4**
#
# **Can you explain the different elements printed on the last output?** df.info() fait un résumé du DataFrame en donnant le nom des colonnes, le type de leur contenu et du nombre de valeur non null.

# %%
df1 = df[(df.Country == "France") & (df.Year > 2010)]
print("df1: ", df1)
df2 = df[(df.Country == "France")].Year
print("df2: ", df2)
# Out:
# df1:      Country  Longitude  Latitude Continent  Year      Status  Life_expectancy  \
# 931  France  -2.761729  42.17344    Europe  2014  Developing             82.2
# 932  France  -2.761729  42.17344    Europe  2013  Developing             82.0
# 933  France  -2.761729  42.17344    Europe  2012  Developing             81.5
# 934  France  -2.761729  42.17344    Europe  2011  Developing             81.7
#
#      Adult_mortality  Infant_deaths  Alcohol  ...  Polio  Total_expenditure  \
# 931             79.0              3     11.5  ...   98.0              11.54
# 932             81.0              3     11.1  ...   99.0              11.56
# 933             83.0              3     11.5  ...   99.0              11.44
# 934             83.0              3     11.8  ...   99.0              11.33
#
#      Diphtheria  HIV_AIDS          GDP  Population  Thinness _1-19_years  \
# 931        98.0       0.1  42955.24287  66331957.0                   0.6
# 932        99.0       0.1  42554.12250   6599857.0                   0.6
# 933        99.0       0.1   4838.24440   6565979.0                   0.6
# 934        99.0       0.1   4381.28800  65342776.0                   0.6
#
#      Thinness_5-9_years  Income_composition_of_resources  Schooling
# 931                 0.6                            0.890       16.2
# 932                 0.6                            0.887       16.2
# 933                 0.6                            0.885       16.1
# 934                 0.6                            0.882       16.1
#
# [4 rows x 25 columns]
# df2:  931    2014
# 932    2013
# 933    2012
# 934    2011
# 935    2010
# 936    2009
# 937    2008
# 938    2007
# 939    2006
# 940    2005
# 941    2004
# 942    2003
# 943    2002
# 944    2001
# 945    2000
# Name: Year, dtype: int64

# %% [markdown]
# **QUESTION 5**
#
# **How do you interpret the new Data Frame df1 compared to df?** df1 est la restriction de df en prenant seulement les lignes avec comme pays la France et comme année au dessus de 2010
# **What represents df2 compared to df1?** df2 correspond seulement aux années où les données sont présentes pour la France

# %% [markdown]
# **TO CODE 2.2**
#
# What is the range of life expectancy of Belgium between 2004 and 2008?

# %%
dfB=df[(df.Country == "Belgium") & (df.Year >= 2004) & (df.Year <= 2008)]
print( "The life expectancy in belgium between 2004 and 2008 is between",dfB.Life_expectancy.min(),"and",dfB.Life_expectancy.max())
# Out:
# The life expectancy in belgium between 2004 and 2008 is between 78.8 and 79.5

# %% [markdown]
# **TO DO 2.3**
#
# Compute the correlation among all features

# %%
print(df.corr())
# Out:
#                                  Longitude  Latitude      Year  \
# Longitude                         1.000000  0.064602 -0.018635
# Latitude                          0.064602  1.000000 -0.027252
# Year                             -0.018635 -0.027252  1.000000
# Life_expectancy                  -0.192675  0.432515  0.050771
# Adult_mortality                   0.091557 -0.348847 -0.037092
# Infant_deaths                     0.140981 -0.002955  0.008029
# Alcohol                          -0.202308  0.349825 -0.113365
# Percentage_expenditure           -0.057579  0.214447  0.069553
# Hepatitis_B                       0.012114  0.060178  0.114897
# Measles                           0.168937  0.033374 -0.053822
# BMI                              -0.233330  0.268139  0.005739
# Under-five_deaths                 0.134130 -0.011890  0.010479
# Polio                            -0.002238  0.179645 -0.016699
# Total_expenditure                -0.200847  0.043328  0.059493
# Diphtheria                       -0.026703  0.189472  0.029641
# HIV_AIDS                          0.027877 -0.388946 -0.123405
# GDP                              -0.049566  0.250799  0.096421
# Population                        0.068179  0.010934  0.012567
# Thinness _1-19_years              0.282557 -0.155765  0.019757
# Thinness_5-9_years                0.308874 -0.162645  0.014122
# Income_composition_of_resources  -0.227682  0.330439  0.122892
# Schooling                        -0.151183  0.279783  0.088732
#
#                                  Life_expectancy  Adult_mortality  \
# Longitude                              -0.192675         0.091557
# Latitude                                0.432515        -0.348847
# Year                                    0.050771        -0.037092
# Life_expectancy                         1.000000        -0.702523
# Adult_mortality                        -0.702523         1.000000
# Infant_deaths                          -0.169074         0.042450
# Alcohol                                 0.402718        -0.175535
# Percentage_expenditure                  0.409631        -0.237610
# Hepatitis_B                             0.199935        -0.105225
# Measles                                -0.068881        -0.003967
# BMI                                     0.542042        -0.351542
# Under-five_deaths                      -0.192265         0.060365
# Polio                                   0.327294        -0.199853
# Total_expenditure                       0.174718        -0.085227
# Diphtheria                              0.341331        -0.191429
# HIV_AIDS                               -0.592236         0.550691
# GDP                                     0.441322        -0.255035
# Population                             -0.022305        -0.015012
# Thinness _1-19_years                   -0.457838         0.272230
# Thinness_5-9_years                     -0.457508         0.286723
# Income_composition_of_resources         0.721083        -0.442203
# Schooling                               0.727630        -0.421171
#
#                                  Infant_deaths   Alcohol  \
# Longitude                             0.140981 -0.202308
# Latitude                             -0.002955  0.349825
# Year                                  0.008029 -0.113365
# Life_expectancy                      -0.169074  0.402718
# Adult_mortality                       0.042450 -0.175535
# Infant_deaths                         1.000000 -0.106217
# Alcohol                              -0.106217  1.000000
# Percentage_expenditure               -0.090765  0.417047
# Hepatitis_B                          -0.231769  0.109889
# Measles                               0.532680 -0.050110
# BMI                                  -0.234425  0.353396
# Under-five_deaths                     0.996906 -0.101082
# Polio                                -0.156929  0.240315
# Total_expenditure                    -0.146951  0.214885
# Diphtheria                           -0.161871  0.242951
# HIV_AIDS                              0.007712 -0.027113
# GDP                                  -0.098092  0.443433
# Population                            0.671758 -0.028880
# Thinness _1-19_years                  0.463415 -0.403755
# Thinness_5-9_years                    0.461908 -0.386208
# Income_composition_of_resources      -0.134754  0.561074
# Schooling                            -0.214372  0.616975
#
#                                  Percentage_expenditure  Hepatitis_B  \
# Longitude                                     -0.057579     0.012114
# Latitude                                       0.214447     0.060178
# Year                                           0.069553     0.114897
# Life_expectancy                                0.409631     0.199935
# Adult_mortality                               -0.237610    -0.105225
# Infant_deaths                                 -0.090765    -0.231769
# Alcohol                                        0.417047     0.109889
# Percentage_expenditure                         1.000000     0.016760
# Hepatitis_B                                    0.016760     1.000000
# Measles                                       -0.063071    -0.124800
# BMI                                            0.242738     0.143302
# Under-five_deaths                             -0.092158    -0.240766
# Polio                                          0.128626     0.463331
# Total_expenditure                              0.183872     0.113327
# Diphtheria                                     0.134813     0.588990
# HIV_AIDS                                      -0.095085    -0.094802
# GDP                                            0.959299     0.041850
# Population                                    -0.016792    -0.129723
# Thinness _1-19_years                          -0.255035    -0.129406
# Thinness_5-9_years                            -0.255635    -0.133251
# Income_composition_of_resources                0.402170     0.184921
# Schooling                                      0.422088     0.215182
#
#                                   Measles  ...     Polio  Total_expenditure  \
# Longitude                        0.168937  ... -0.002238          -0.200847
# Latitude                         0.033374  ...  0.179645           0.043328
# Year                            -0.053822  ... -0.016699           0.059493
# Life_expectancy                 -0.068881  ...  0.327294           0.174718
# Adult_mortality                 -0.003967  ... -0.199853          -0.085227
# Infant_deaths                    0.532680  ... -0.156929          -0.146951
# Alcohol                         -0.050110  ...  0.240315           0.214885
# Percentage_expenditure          -0.063071  ...  0.128626           0.183872
# Hepatitis_B                     -0.124800  ...  0.463331           0.113327
# Measles                          1.000000  ... -0.057850          -0.113583
# BMI                             -0.153245  ...  0.186268           0.189469
# Under-five_deaths                0.517506  ... -0.171164          -0.145803
# Polio                           -0.057850  ...  1.000000           0.119768
# Total_expenditure               -0.113583  ...  0.119768           1.000000
# Diphtheria                      -0.058606  ...  0.609245           0.129915
# HIV_AIDS                        -0.003522  ... -0.107885           0.043101
# GDP                             -0.064768  ...  0.156809           0.180373
# Population                       0.321946  ... -0.045387          -0.079962
# Thinness _1-19_years             0.180642  ... -0.164070          -0.209872
# Thinness_5-9_years               0.174946  ... -0.174489          -0.217865
# Income_composition_of_resources -0.058277  ...  0.314682           0.183653
# Schooling                       -0.115660  ...  0.350147           0.243783
#
#                                  Diphtheria  HIV_AIDS       GDP  Population  \
# Longitude                         -0.026703  0.027877 -0.049566    0.068179
# Latitude                           0.189472 -0.388946  0.250799    0.010934
# Year                               0.029641 -0.123405  0.096421    0.012567
# Life_expectancy                    0.341331 -0.592236  0.441322   -0.022305
# Adult_mortality                   -0.191429  0.550691 -0.255035   -0.015012
# Infant_deaths                     -0.161871  0.007712 -0.098092    0.671758
# Alcohol                            0.242951 -0.027113  0.443433   -0.028880
# Percentage_expenditure             0.134813 -0.095085  0.959299   -0.016792
# Hepatitis_B                        0.588990 -0.094802  0.041850   -0.129723
# Measles                           -0.058606 -0.003522 -0.064768    0.321946
# BMI                                0.176295 -0.210897  0.266114   -0.081416
# Under-five_deaths                 -0.178448  0.019476 -0.100331    0.658680
# Polio                              0.609245 -0.107885  0.156809   -0.045387
# Total_expenditure                  0.129915  0.043101  0.180373   -0.079962
# Diphtheria                         1.000000 -0.117601  0.158438   -0.039898
# HIV_AIDS                          -0.117601  1.000000 -0.108081   -0.027801
# GDP                                0.158438 -0.108081  1.000000   -0.020369
# Population                        -0.039898 -0.027801 -0.020369    1.000000
# Thinness _1-19_years              -0.187242  0.172592 -0.277498    0.282529
# Thinness_5-9_years                -0.180952  0.183147 -0.277959    0.277913
# Income_composition_of_resources    0.343262 -0.248590  0.446856   -0.008132
# Schooling                          0.350398 -0.211840  0.467947   -0.040312
#
#                                  Thinness _1-19_years  Thinness_5-9_years  \
# Longitude                                    0.282557            0.308874
# Latitude                                    -0.155765           -0.162645
# Year                                         0.019757            0.014122
# Life_expectancy                             -0.457838           -0.457508
# Adult_mortality                              0.272230            0.286723
# Infant_deaths                                0.463415            0.461908
# Alcohol                                     -0.403755           -0.386208
# Percentage_expenditure                      -0.255035           -0.255635
# Hepatitis_B                                 -0.129406           -0.133251
# Measles                                      0.180642            0.174946
# BMI                                         -0.547018           -0.554094
# Under-five_deaths                            0.464785            0.462289
# Polio                                       -0.164070           -0.174489
# Total_expenditure                           -0.209872           -0.217865
# Diphtheria                                  -0.187242           -0.180952
# HIV_AIDS                                     0.172592            0.183147
# GDP                                         -0.277498           -0.277959
# Population                                   0.282529            0.277913
# Thinness _1-19_years                         1.000000            0.927913
# Thinness_5-9_years                           0.927913            1.000000
# Income_composition_of_resources             -0.453679           -0.438484
# Schooling                                   -0.491199           -0.472482
#
#                                  Income_composition_of_resources  Schooling
# Longitude                                              -0.227682  -0.151183
# Latitude                                                0.330439   0.279783
# Year                                                    0.122892   0.088732
# Life_expectancy                                         0.721083   0.727630
# Adult_mortality                                        -0.442203  -0.421171
# Infant_deaths                                          -0.134754  -0.214372
# Alcohol                                                 0.561074   0.616975
# Percentage_expenditure                                  0.402170   0.422088
# Hepatitis_B                                             0.184921   0.215182
# Measles                                                -0.058277  -0.115660
# BMI                                                     0.510505   0.554844
# Under-five_deaths                                      -0.148097  -0.226013
# Polio                                                   0.314682   0.350147
# Total_expenditure                                       0.183653   0.243783
# Diphtheria                                              0.343262   0.350398
# HIV_AIDS                                               -0.248590  -0.211840
# GDP                                                     0.446856   0.467947
# Population                                             -0.008132  -0.040312
# Thinness _1-19_years                                   -0.453679  -0.491199
# Thinness_5-9_years                                     -0.438484  -0.472482
# Income_composition_of_resources                         1.000000   0.784741
# Schooling                                               0.784741   1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# **QUESTION 6**
#
# **Which seems the most and the least promising values to use as a predictor for life expectancy?** The best seems to be Shooling and the least seems to be Population

# %% [markdown]
# The function scatter of matplotlib allows to plot two values against each other. Here is the documentation about this function:
#
# ```
# matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)
# ```
# Parameters:
#
# **x, y** float or array-like, shape (n, )
#
# The data positions.
#
# **s** float or array-like, shape (n, ), optional
#
# The marker size in points**2. Default is rcParams['lines.markersize'] ** 2.
#
# **c** array-like or list of colors or color, optional
#
# The marker colors. Possible values:
#
# - A scalar or sequence of n numbers to be mapped to colors using cmap and norm.
#
# - A 2D array in which the rows are RGB or RGBA.
#
# - A sequence of colors of length n.
#
# - A single color format string.
#
# **marker** MarkerStyle, default: rcParams (default: 'o')
#
# The marker style. marker can be either an instance of the class or the text shorthand for a particular marker. See matplotlib.markers for more information about marker styles.
#
# **cmapstr** or Colormap, default: rcParams(default: 'viridis')
#
# A Colormap instance or registered colormap name. cmap is only used if c is an array of floats.
#
# **norm** Normalize, default: None
#
# If c is an array of floats, norm is used to scale the color data, c, in the range 0 to 1, in order to map into the colormap cmap. If None, use the default colors.Normalize.
#
# **vmin, vmax** float, default: None
#
# vmin and vmax are used in conjunction with the default norm to map the color array c to the colormap cmap. If None, the respective min and max of the color array is used. It is deprecated to use vmin/vmax when norm is given.
#
# **alpha** float, default: None
#
# The alpha blending value, between 0 (transparent) and 1 (opaque).
#
# **linewidths** float or array-like, default: rcParams (default: 1.5)
#
# The linewidth of the marker edges. Note: The default edgecolors is 'face'. You may want to change this as well.
#
# **edgecolors** {'face', 'none', None} or color or sequence of color, default: rcParams["scatter.edgecolors"] (default: 'face')
#
# The edge color of the marker. Possible values:
#
# - 'face': The edge color will always be the same as the face color.
#
# - 'none': No patch boundary will be drawn.
#
# - A color or sequence of colors.
#
# For non-filled markers, edgecolors is ignored. Instead, the color is determined like with 'face', i.e. from c, colors, or facecolors.
#
# **plotnonfinite** bool, default: False
#
# Whether to plot points with nonfinite c (i.e. inf, -inf or nan). If True the points are drawn with the bad colormap color (see Colormap.set_bad).

# %% [markdown]
# **TO CODE 2.4**
#
# Plot life expectancy against one of your chosen values.

# %%
plt.scatter(df["Schooling"],df["Life_expectancy"])
plt.title("Life_expectancy=f(Schooling)")
plt.show()

# %% [markdown]
# ## STEP 3: Simple Linear Regression

# %%
import numpy as np

# %% [markdown]
# **TO CODE 3.1**
#
# Select the Life Expectancy and the Income composition of resources of Belarus, Madagascar, India and Lithuania. This new Data Frame will be called df_study

# %%
df_study=df[(df.Country == "Belarus") | (df.Country == "Madagascar") | (df.Country == "India") | (df.Country == "Lithuania")]
df_study=df_study[["Life_expectancy","Income_composition_of_resources"]]
df_study
# Out:
#       Life_expectancy  Income_composition_of_resources
# 225              72.0                            0.796
# 226              71.7                            0.796
# 227              71.9                            0.793
# 228              72.0                            0.787
# 229              73.0                            0.780
# 230              70.0                            0.771
# 231              70.0                            0.755
# 232              69.8                            0.739
# 233              68.9                            0.723
# 234              68.1                            0.713
# 235              68.2                            0.703
# 236              67.7                            0.695
# 237              67.2                            0.687
# 238              67.7                            0.681
# 239              68.0                            0.675
# 1187             68.0                            0.607
# 1188             67.6                            0.599
# 1189             67.3                            0.590
# 1190             66.8                            0.580
# 1191             66.4                            0.569
# 1192             66.0                            0.563
# 1193             65.5                            0.556
# 1194             65.2                            0.546
# 1195             64.8                            0.536
# 1196             64.4                            0.526
# 1197             64.0                            0.518
# 1523             73.4                            0.841
# 1524             73.0                            0.834
# 1525             73.0                            0.830
# 1526             72.8                            0.826
# 1527             72.4                            0.824
# 1528             72.2                            0.825
# 1529             71.1                            0.820
# 1530             72.0                            0.812
# 1531             76.0                            0.807
# 1532             78.0                            0.798
# 1533             71.6                            0.792
# 1534             71.6                            0.780
# 1535             71.4                            0.770
# 1536             71.2                            0.757
# 1537             71.6                            0.745
# 1555             65.1                            0.509
# 1556             64.7                            0.508
# 1557             64.3                            0.506
# 1558             63.8                            0.504
# 1559             63.3                            0.503
# 1560             62.8                            0.500
# 1561             62.3                            0.491
# 1562             61.9                            0.483
# 1563             61.4                            0.478
# 1564             69.0                            0.473
# 1565             64.0                            0.466
# 1566             59.9                            0.457
# 1567             59.3                            0.462

# %% [markdown]
# **TO CODE 3.2**
#
# Implement a simple least square function and apply it on the previous selected data.

# %%
def SimpleLeastSquare(x,y):
    n=np.linspace(np.min(x),np.max(x),100)
    mean_x=np.sum(x)/np.size(x)
    mean_y=np.sum(y)/np.size(y)
    xmm=x-mean_x
    ymm=y-mean_y
    b1=(np.sum(xmm*ymm)) / (np.sum(xmm*xmm))
    b0=mean_y-b1*mean_x
    yn=b1*n+b0
    print(b0,b1)
    return(n,yn)

# %%
x=df_study["Income_composition_of_resources"].values
y=df_study["Life_expectancy"].values
(x_linspace,y_predict_linspace)=(SimpleLeastSquare(x,y))
# Out:
# 49.34763518833232 28.5982261406769

# %% [markdown]
# **TO CODE 3.3**
#
# On the same figure, draw the line corresponding to your regression and the data points corres-
# ponding to df_study

# %%
plt.plot(x_linspace,y_predict_linspace)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **TO CODE 3.4**
#
# Now, implement a Gradient Descend function `def gradDescent(x, y, theta, alpha, iters)` where `x` are
# the covariates, `y` the target value, `theta` the initial weights, `alpha` the learning rate and `iters` the number
# of gradient descent iterations. Your function should return all intermediary values of `theta` that has been computed as a list.

# %%
def gradDescent(x, y, theta, alpha, iters):
    Lw = [(theta[0], theta[1])]
    a = 0
    b = 0 
    for k in range(iters):
        jwb0= 0
        jwb1= 0
        for i in range(len(y)):
            jwb0 += -2*(y[i]-Lw[k][0]-Lw[k][1]*x[i])
            jwb1 += -2*x[i]*(y[i]-Lw[k][0]-Lw[k][1]*x[i])
        jwb0=jwb0/len(y)
        jwb1=jwb1/len(y)

        a = Lw[k][0] - alpha*jwb0
        b = Lw[k][1] - alpha*jwb1
        Lw.append((a,b))
    return Lw

# %% [markdown]
# **TO CODE 3.5**
#
# Compute the gradient descend on df_study for 1000 iterations with different values of `alpha`. You
# may initialize `theta` with `theta_0 = 0` and `theta_1 = 1`

# %%
List002 = gradDescent(df_study["Income_composition_of_resources"].values,df_study["Life_expectancy"].values, [0,1], 0.002, 1000)
List01 = gradDescent(df_study["Income_composition_of_resources"].values,df_study["Life_expectancy"].values, [0,1], 0.01, 1000)
List1 = gradDescent(df_study["Income_composition_of_resources"].values,df_study["Life_expectancy"].values, [0,1], 0.1, 1000)
List2 = gradDescent(df_study["Income_composition_of_resources"].values,df_study["Life_expectancy"].values, [0,1], 0.2, 1000)

# %% [markdown]
# **TO CODE 3.6**
#
# On the same figure, plot the evolution of theta_0 through the iterations for each different values of
# alpha you chose. Do the same thing for theta_1.

# %%
Lb0_002=[]
Lb1_002=[]
for i in List002:
    Lb0_002.append(i[0])
    Lb1_002.append(i[1])

Lb0_01=[]
Lb1_01=[]
for i in List01:
    Lb0_01.append(i[0])
    Lb1_01.append(i[1])

Lb0_1=[]
Lb1_1=[]
for i in List1:
    Lb0_1.append(i[0])
    Lb1_1.append(i[1])

Lb0_2=[]
Lb1_2=[]
for i in List2:
    Lb0_2.append(i[0])
    Lb1_2.append(i[1])

# %%
plt.plot(range(len(List002)),Lb0_002)
plt.plot(range(len(List01)),Lb0_01)
plt.plot(range(len(List1)),Lb0_1)
plt.plot(range(len(List2)),Lb0_2)
plt.legend(["0.05","0.01","0.1","0.2"])
plt.show()

# %%
plt.plot(range(len(List002)),Lb1_002)
plt.plot(range(len(List01)),Lb1_01)
plt.plot(range(len(List1)),Lb1_1)
plt.plot(range(len(List2)),Lb1_2)
plt.legend(["0.05","0.01","0.1","0.2"])
plt.show()

# %% [markdown]
# **Question 7**
#
# **Discuss on the role of alpha**
#
# Alpha va permettre de conrôler la vitesse à laquelle les poids convergent vers leur valeur optimales

# %% [markdown]
# $R^2$ is the coefficient of determination useful to score a regression against the ground truth data.
#
# This coefficient can be computed with a sklearn function:
#
# ```
# sklearn.metrics.r2_score(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')
# ```
#
# With:
#
# **y_true** array-like of shape (n_samples,) or (n_samples, n_outputs)
#
# Ground truth (correct) target values.
#
# **y_pred** array-like of shape (n_samples,) or (n_samples, n_outputs)
#
# Estimated target values.
#
# **sample_weight** array-like of shape (n_samples,), default=None
#
# Sample weights.
#
# **multioutput** {‘raw_values’, ‘uniform_average’, ‘variance_weighted’}, array-like of shape (n_outputs,) or None, default=’uniform_average’
#
# Defines aggregating of multiple output scores. Array-like value defines weights used to average scores. Default is “uniform_average”.
#
# - ‘raw_values’: Returns a full set of scores in case of multioutput input.
#
# - ‘uniform_average’: Scores of all outputs are averaged with uniform weight.
#
# - ‘variance_weighted’: Scores of all outputs are averaged, weighted by the variances of each individual output.

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# **TO CODE 3.7**
#
# Compute $R^2$ on the regression with df_study

# %%
b=List1[-1]
y_predict=[]
for i in range(x.size):
    y_predict.append(b[0]+x[i]*b[1])
y_predict
plt.scatter(x,y_predict)
plt.scatter(x,y)
plt.legend(["Prédiction","Vraies valeurs"])
plt.show()
r2_score(y,y_predict)
# Out:
# 0.8465227575976074

# %% [markdown]
# **QUESTION 8**
#
# **Is linear regression suited between the two selected variables?** $R^2=0.84$ proche de 1, c'est un assez bonne prédcition

# %% [markdown]
# **QUESTION 9**
#
# **If not, what would be the relevant regression between these two variables?** order 3 polynomial may be better

# %% [markdown]
# ## STEP 4: Multivariate regression

# %% [markdown]
# **TO DO 4.1**
#
# Execute the following cells

# %%
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error

df_study = df[(df.Country == "Belarus") | (df.Country == "Madagascar") | (df.Country == "India") | (df.Country == "Lithuania")]
y = df_study.Life_expectancy
X = df_study[['Adult_mortality', 'Alcohol', 'Total_expenditure', 'Income_composition_of_resources', 'Schooling', "HIV_AIDS"]].to_numpy(dtype='float64')

alphas = 10**np.linspace(10,-2,100)*0.5

# %%
ridge = Ridge(normalize = True)
coefs = []

for a in alphas:
    ridge.set_params(alpha = a)
    ridge.fit(X, y)
    coefs.append(list(ridge.coef_))

ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.legend(['Adult_mortality', 'Alcohol', 'Total_expenditure', 'Income_composition_of_resources', 'Schooling', "HIV_AIDS"])
plt.show()
# Out:
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# ...
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(

# %% [markdown]
# **QUESTION 10**
#
# **How do you interpret the plot?**
# Le terme alpha est un terme de pondération des grandes valeurs de poids qui définit l'importance de la minimisation du modèle calculé. Ainsi, lorsqu'il augmente, l'importance du modèle diminue, par conséquent les poids tendent vers 0.

# %% [markdown]
# **QUESTION 11**
#
# **Is it normal that the l2 diminishes with alpha increasing?** Oui car c'est la norme 2 des poids. Or les poids tendent vers 0 lorsque alpha augmente donc la norme 2 du vecteur poids diminue.

# %% [markdown]
# **QUESTION 12**
#
# **Which is the most relevant variable for Ridge? Prove and justify your response in the following cell.** The weight of Income composition of resources is the highest and the correlation between Life expectancy and Income composition of resources is the highest too ( for life expectancy) so the most relevant variable is Income composition of resources

# %%
df_study[['Adult_mortality', 'Alcohol', 'Total_expenditure', 'Income_composition_of_resources', 'Schooling', "HIV_AIDS",'Life_expectancy']].corr()["Life_expectancy"]
# Out:
# Adult_mortality                   -0.263012
# Alcohol                            0.840457
# Total_expenditure                  0.643388
# Income_composition_of_resources    0.920126
# Schooling                          0.913310
# HIV_AIDS                          -0.819865
# Life_expectancy                    1.000000
# Name: Life_expectancy, dtype: float64

# %% [markdown]
# **TO DO 4.2**
#
# Execute the following cell

# %%
lasso = Lasso(normalize = True)
coefs = []

for a in alphas:
    lasso.set_params(alpha = a)
    lasso.fit(X, y)
    coefs.append(lasso.coef_)

ax = plt.gca()
ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.show()
# Out:
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(

# %% [markdown]
# **QUESTION 13**
#
# **Which is the most relevant variable for Lasso? Prove and justify your response in the following cell.** same as the last question -> Income composition of resources

# %% [markdown]
# **QUESTION 14**
#
# **What is the main difference between Ridge and Lasso regression? For this setup, which is the prefered method to use? Justify your response** La décroissance des poids en fonction de alpha est plus rapide avec Lasso qu'avec Ridge. Lasso utilise un terme en norme 1 des poids pour minimiser les poids tandis que Ridge utilise un terme en norme 2 des poids. Les coefficients peuvent atteindre 0 avec Lasso. Ainsi Lasso peut annuler certains coefficient et non Ridge, cela signifie que pour des variables fortement corrélées, il est préférable d'utiliser Ridge pour ne pas que des coefficients importants s'annulent et décorrèlent les variables. Ainsi nous devons utiliser Ridge dans notre cas.

# %% [markdown]
# ** TO CODE 4.3 **
#
# Following the previous examples, use a sklearn function to compute a multivariable least square method. Compare the coefficients obtained by the different methods.

# %%
import sklearn
from sklearn.linear_model import LinearRegression
model=LinearRegression(normalize=True)
model.fit(X,y)
print(model.coef_,model.intercept_)
plt.scatter(y,model.predict(X))
r2_score(y,model.predict(X))
# Out:
# [ 2.65943031e-03 -3.17928713e-01 -7.99041602e-01  4.49600718e+01
#   1.33103670e-01  1.25430166e-02] 43.28154551372652
# /Users/yohanismael/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# 0.8794497128525169

# %% [markdown]
# **TO CODE 4.4 **
#
# Dealing with too many variables can sometimes be counter-productive and it can be more interesting to remove some features. One way to evaluate the importance of each variable is to compute the f_test whose function is named f_regression in sklearn.

# %%
from sklearn.feature_selection import f_regression
regression=f_regression(X,y)
list(regression[0])
# Out:
# [3.864442141527443,
#  125.09281253190987,
#  36.729420299951016,
#  287.05437637776515,
#  261.50896011400374,
#  106.62272299833975]

# %% [markdown]
# **QUESTION 15**
#
# According to the f_test, rank each variable from the least to the most promising. Compare it with the correlation of your subset.

# %% [markdown]
# Income_composition_of_resources -> Schooling -> Alcohol -> HIV_AIDS -> Total_expenditure -> Adult_mortality

# %%
df_study[['Adult_mortality', 'Alcohol', 'Total_expenditure', 'Income_composition_of_resources', 'Schooling', "HIV_AIDS",'Life_expectancy']].corr()["Life_expectancy"]
# Out:
# Adult_mortality                   -0.263012
# Alcohol                            0.840457
# Total_expenditure                  0.643388
# Income_composition_of_resources    0.920126
# Schooling                          0.913310
# HIV_AIDS                          -0.819865
# Life_expectancy                    1.000000
# Name: Life_expectancy, dtype: float64

# %% [markdown]
# f_test is ranking the variables just like we do with the correlation of the subset
